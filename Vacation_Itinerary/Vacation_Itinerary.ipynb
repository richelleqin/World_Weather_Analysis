# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID         City Country  Max Temp       Description      Lat  \
# 0        0   Georgetown      MY     84.13        few clouds   5.4112
# 1        1       Avarua      CK     82.45  scattered clouds -21.2078
# 2        2   Vila Velha      BR     76.95         clear sky -20.3297
# 3        9       Atuona      PF     78.69        light rain  -9.8000
# 4       11  New Norfolk      AU     73.71         clear sky -42.7826
#
#         Lng                       Hotel Name
# 0  100.3354                   Cititel Penang
# 1 -159.7750                     Paradise Inn
# 2  -40.2925        Quality Suites Vila Velha
# 3 -139.0333                      Villa Enata
# 4  147.0587  The Shingles Riverside Cottages

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Description} and {Max Temp} °F </dd>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]
hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Cititel Penang</dd>\n<dt>City</dt><dd>Georgetown</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>few clouds and 84.13 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Inn</dd>\n<dt>City</dt><dd>Avarua</dd>\n<dt>Country</dt><dd>CK</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 82.45 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Quality Suites Vila Velha</dd>\n<dt>City</dt><dd>Vila Velha</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>clear sky and 76.95 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Enata</dd>\n<dt>City</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>light rain and 78.69 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Shingles Riverside Cottages</dd>\n<dt>City</dt><dd>New Norfolk</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 73.71 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sheraton Kauai Coconut Beach Resort</dd>\n<dt>City</dt><dd>Kapaa</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>clear sky and 79.12 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Finch Bay Galapagos Hotel</dd>\n<dt>City</dt><dd>Puerto Ayora</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 75.54 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bora-Bora Pearl Beach Resort & Spa</dd>\n<dt>City</dt><dd>Faanui</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>moderate rain and 79.81 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Raiders Hotel & Dive</dd>\n<dt>City</dt><dd>Tulagi</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Weather Description</dt><dd>broken clouds and 84.0 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Chambres d\'hôte "La Trinité"</dd>\n<dt>City</dt><dd>Saint-Philippe</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Weather Description</dt><dd>light rain and 78.39 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Scoop Guest House</dd>\n<dt>City</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>clear sky and 81.81 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Imagination Island</dd>\n<dt>City</dt><dd>Gizo</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 86.49 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Xaguate</dd>\n<dt>City</dt><dd>Sao Filipe</dd>\n<dt>Country</dt><dd>CV</dd>\n<dt>Weather Description</dt><dd>clear sky and 72.75 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Isles Sunset Lodge</dd>\n<dt>City</dt><dd>Butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 82.83 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Ortiz</dd>\n<dt>City</dt><dd>Tocache</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Weather Description</dt><dd>broken clouds and 70.39 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilo Hawaiian Hotel</dd>\n<dt>City</dt><dd>Hilo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>few clouds and 78.53 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La Caz Oceane</dd>\n<dt>City</dt><dd>Saint-Leu</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 77.86 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Atlantis Hotel</dd>\n<dt>City</dt><dd>Bathsheba</dd>\n<dt>Country</dt><dd>BB</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 79.41 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Sri Krishna Residency</dd>\n<dt>City</dt><dd>Malpe</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 70.9 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mantra on Collins Hobart</dd>\n<dt>City</dt><dd>Hobart</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>few clouds and 74.05 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Observatory Guest House</dd>\n<dt>City</dt><dd>Busselton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 74.05 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lorengau Harbourside Hotel</dd>\n<dt>City</dt><dd>Lorengau</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 82.89 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>SEGAYA PROPERTY</dd>\n<dt>City</dt><dd>Dingle</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 82.44 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Keleti Beach Resort</dd>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Weather Description</dt><dd>light rain and 77.16 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>People ThankYou</dd>\n<dt>City</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 79.43 °F </dd>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Piriquitu's</dd>\n<dt>City</dt><dd>Mirandopolis</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 73.02 °F </dd>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La Riviera Hotel Colonial</dd>\n<dt>City</dt><dd>La Primavera</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Weather Description</dt><dd>broken clouds and 84.06 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Montana Hotel Syariah</dd>\n<dt>City</dt><dd>Martapura</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 82.49 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lamu House</dd>\n<dt>City</dt><dd>Lamu</dd>\n<dt>Country</dt><dd>KE</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 77.22 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>CEJ - Centro Escoteiro da Juventude</dd>\n<dt>City</dt><dd>Sao Miguel</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 80.92 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Misty Waves Boutique Hotel</dd>\n<dt>City</dt><dd>Hermanus</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>broken clouds and 71.91 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel</dd>\n<dt>City</dt><dd>Salalah</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Weather Description</dt><dd>broken clouds and 71.69 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aryaduta Hotel</dd>\n<dt>City</dt><dd>Manado</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 86.77 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rydges Port Macquarie</dd>\n<dt>City</dt><dd>Port Macquarie</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>light rain and 72.9 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ahipara Holiday Park</dd>\n<dt>City</dt><dd>Ahipara</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Weather Description</dt><dd>light rain and 74.57 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Desert Gardens Hotel - Ayers Rock Resort</dd>\n<dt>City</dt><dd>Yulara</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 85.84 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Kecubung Hotel</dd>\n<dt>City</dt><dd>Pangkalanbuun</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>light rain and 89.38 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto Praia</dd>\n<dt>City</dt><dd>Arraial Do Cabo</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>broken clouds and 76.41 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Codrington Gardens Bed And Breakfast</dd>\n<dt>City</dt><dd>Codrington</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 79.2 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nusa Island Retreat</dd>\n<dt>City</dt><dd>Kavieng</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 83.82 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grage Hotel Bengkulu</dd>\n<dt>City</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 74.26 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Complexo da Familia</dd>\n<dt>City</dt><dd>Xai-Xai</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Weather Description</dt><dd>clear sky and 76.5 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kost Pria</dd>\n<dt>City</dt><dd>Meulaboh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 81.34 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bambuda hotel</dd>\n<dt>City</dt><dd>Punta Cardon</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Weather Description</dt><dd>clear sky and 77.65 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospitality Carnarvon</dd>\n<dt>City</dt><dd>Carnarvon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 82.47 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Axim Beach Resort And Spa</dd>\n<dt>City</dt><dd>Axim</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Weather Description</dt><dd>light rain and 78.39 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Tia Villa</dd>\n<dt>City</dt><dd>Bambous Virieux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 80.22 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel FX 72</dd>\n<dt>City</dt><dd>Ruteng</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>few clouds and 75.97 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Castelo</dd>\n<dt>City</dt><dd>Cidreira</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 73.71 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bungalow 63</dd>\n<dt>City</dt><dd>Hambantota</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Weather Description</dt><dd>few clouds and 73.74 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>VS Villa</dd>\n<dt>City</dt><dd>Kalmunai</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 78.82 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Flamingo</dd>\n<dt>City</dt><dd>Quelimane</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 76.95 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Posada Villaven C.A.</dd>\n<dt>City</dt><dd>San Cristobal</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 71.78 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Riande Urban Hotel</dd>\n<dt>City</dt><dd>Panama City</dd>\n<dt>Country</dt><dd>PA</dd>\n<dt>Weather Description</dt><dd>few clouds and 78.75 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Broadwater Mariner Resort</dd>\n<dt>City</dt><dd>Geraldton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 81.01 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>እንደገና ገዋኔ ሞቴል</dd>\n<dt>City</dt><dd>Gewane</dd>\n<dt>Country</dt><dd>ET</dd>\n<dt>Weather Description</dt><dd>broken clouds and 71.62 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Novo Hotel</dd>\n<dt>City</dt><dd>Balsas</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>broken clouds and 74.73 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>McCracken Country Club</dd>\n<dt>City</dt><dd>Victor Harbor</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 86.72 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shanti Maurice Resort & Spa</dd>\n<dt>City</dt><dd>Souillac</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 80.37 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Portal del Sol</dd>\n<dt>City</dt><dd>Formosa</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>clear sky and 76.98 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Halane Hotel and Restaurent</dd>\n<dt>City</dt><dd>Hobyo</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Weather Description</dt><dd>few clouds and 74.75 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Halyards Hotel</dd>\n<dt>City</dt><dd>Port Alfred</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 70.2 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nuli Sapi</dd>\n<dt>City</dt><dd>Samarai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 84.79 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>JABIR HOTEL</dd>\n<dt>City</dt><dd>Bandarbeyla</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Weather Description</dt><dd>clear sky and 72.9 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Regency Hotel</dd>\n<dt>City</dt><dd>Yanam</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>few clouds and 70.2 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Hamsa Resort</dd>\n<dt>City</dt><dd>Banjar</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>heavy intensity rain and 85.91 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Port Lincoln Hotel</dd>\n<dt>City</dt><dd>Port Lincoln</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 78.3 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Historic Hydro Motor Inn</dd>\n<dt>City</dt><dd>Leeton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 80.89 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La Grace Hôtel</dd>\n<dt>City</dt><dd>Kribi</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 77.68 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mercure Padang</dd>\n<dt>City</dt><dd>Padang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 80.65 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Desert Palms Alice Springs</dd>\n<dt>City</dt><dd>Alice Springs</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 81.95 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Dawei</dd>\n<dt>City</dt><dd>Dawei</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 85.42 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>African House Resort</dd>\n<dt>City</dt><dd>Malindi</dd>\n<dt>Country</dt><dd>KE</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 75.79 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Nusantara Nabire</dd>\n<dt>City</dt><dd>Nabire</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 86.27 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Phu Quy Hotel</dd>\n<dt>City</dt><dd>Soc Trang</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 80.56 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rydges Southbank Townsville</dd>\n<dt>City</dt><dd>Townsville</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 83.28 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ungoofaaru Inn</dd>\n<dt>City</dt><dd>Ugoofaaru</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 81.07 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada dos Navegantes</dd>\n<dt>City</dt><dd>Caravelas</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>few clouds and 75.09 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Morotin</dd>\n<dt>City</dt><dd>Santa Maria</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>clear sky and 72.7 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Jhennifer</dd>\n<dt>City</dt><dd>Canutama</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 71.13 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bathurst Motor Inn</dd>\n<dt>City</dt><dd>Bathurst</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 74.71 °F </dd>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Marriott's Ko Olina Beach Club</dd>\n<dt>City</dt><dd>Makakilo City</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 80.92 °F </dd>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sur Plaza Hotel</dd>\n<dt>City</dt><dd>Sur</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Weather Description</dt><dd>clear sky and 70.45 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Screensaver</dd>\n<dt>City</dt><dd>Harper</dd>\n<dt>Country</dt><dd>LR</dd>\n<dt>Weather Description</dt><dd>light rain and 78.49 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Grace Sydney</dd>\n<dt>City</dt><dd>Sidney</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 77.34 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Royal Exchange Hotel</dd>\n<dt>City</dt><dd>Broken Hill</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 80.31 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Osprey Beach Hotel</dd>\n<dt>City</dt><dd>Cockburn Town</dd>\n<dt>Country</dt><dd>TC</dd>\n<dt>Weather Description</dt><dd>clear sky and 76.08 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Veranda Paul et Virginie Hotel & Spa</dd>\n<dt>City</dt><dd>Grand Gaube</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 80.38 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Derogongan Residence</dd>\n<dt>City</dt><dd>Marawi</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>broken clouds and 74.64 °F </dd>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>POUSADA TRAVÉS'CIA</dd>\n<dt>City</dt><dd>Cururupu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 74.68 °F </dd>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Las Cabinas Del Sueño</dd>\n<dt>City</dt><dd>Nicoya</dd>\n<dt>Country</dt><dd>CR</dd>\n<dt>Weather Description</dt><dd>clear sky and 76.55 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guest Hotel</dd>\n<dt>City</dt><dd>Manggar</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 82.26 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>فندق حضرموت</dd>\n<dt>City</dt><dd>Bajil</dd>\n<dt>Country</dt><dd>YE</dd>\n<dt>Weather Description</dt><dd>broken clouds and 73.72 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Al Djadid</dd>\n<dt>City</dt><dd>Domoni</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 79.29 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>East Arnhem Real Estate</dd>\n<dt>City</dt><dd>Nhulunbuy</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 88.41 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>KOPKAR Hotel Bintang Sintuk</dd>\n<dt>City</dt><dd>Bontang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 83.93 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto De Canoas</dd>\n<dt>City</dt><dd>Sao Joao Da Barra</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>clear sky and 76.73 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>"Plantation Bed and Breakfast</dd>\n<dt>City</dt><dd>Saint-Joseph</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Weather Description</dt><dd>light rain and 77.38 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Elimtop</dd>\n<dt>City</dt><dd>Wukari</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Weather Description</dt><dd>clear sky and 70.18 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ENCEIN BUREAU CISCO</dd>\n<dt>City</dt><dd>Ankazoabo</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Weather Description</dt><dd>light rain and 72.59 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Mar Colina</dd>\n<dt>City</dt><dd>Yeppoon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>few clouds and 82.18 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Yarada Jungle Beach Resorts</dd>\n<dt>City</dt><dd>Yarada</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>mist and 71.92 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Dora, Bubaque</dd>\n<dt>City</dt><dd>Bubaque</dd>\n<dt>Country</dt><dd>GW</dd>\n<dt>Weather Description</dt><dd>clear sky and 77.65 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Park Hotel | Natal</dd>\n<dt>City</dt><dd>Natal</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>few clouds and 80.82 °F </dd>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>JBryan Traveler's Inn</dd>\n<dt>City</dt><dd>Araceli</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>broken clouds and 80.33 °F </dd>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tanna Lodge</dd>\n<dt>City</dt><dd>Isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 81.95 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Piaçabuçu News</dd>\n<dt>City</dt><dd>Piacabucu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>broken clouds and 77.61 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auki Motel</dd>\n<dt>City</dt><dd>Auki</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Weather Description</dt><dd>broken clouds and 83.98 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Khách Sạn Bình Phước - Khách Sạn Ngọc Lan</dd>\n<dt>City</dt><dd>Dong Xoai</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 86.92 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Comfort Inn Traralgon</dd>\n<dt>City</dt><dd>Traralgon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 79.84 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Camapuã</dd>\n<dt>City</dt><dd>Gilbues</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>broken clouds and 75.0 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Vila dos Ipês</dd>\n<dt>City</dt><dd>Cavalcante</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 70.23 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Groote Eylandt Lodge</dd>\n<dt>City</dt><dd>Alyangula</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>light rain and 85.87 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>CASA AVALIADA</dd>\n<dt>City</dt><dd>Benjamin Constant</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 77.13 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Al Falaj Hotel</dd>\n<dt>City</dt><dd>Ruwi</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Weather Description</dt><dd>clear sky and 73.62 °F </dd>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Cattleman's Rest Motor Inn</dd>\n<dt>City</dt><dd>Charters Towers</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 86.04 °F </dd>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Red Sea Hotel</dd>\n<dt>City</dt><dd>Bosaso</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 70.65 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Star Guest House</dd>\n<dt>City</dt><dd>Batticaloa</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Weather Description</dt><dd>broken clouds and 79.56 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Spanish Villa</dd>\n<dt>City</dt><dd>Mumford</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Weather Description</dt><dd>light rain and 78.91 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Praia Morena</dd>\n<dt>City</dt><dd>Benguela</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 74.52 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL ARARAS</dd>\n<dt>City</dt><dd>Anastacio</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>moderate rain and 74.41 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>H10 Taburiente Playa</dd>\n<dt>City</dt><dd>Santa Cruz De La Palma</dd>\n<dt>Country</dt><dd>ES</dd>\n<dt>Weather Description</dt><dd>clear sky and 70.14 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maunacaribe</dd>\n<dt>City</dt><dd>Maunabo</dd>\n<dt>Country</dt><dd>PR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 73.42 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tarawa Boutique Hotel</dd>\n<dt>City</dt><dd>Bairiki</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Weather Description</dt><dd>few clouds and 87.8 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ramah Kost KITA</dd>\n<dt>City</dt><dd>Pemangkat</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>broken clouds and 82.65 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>INN NEW HORIZON</dd>\n<dt>City</dt><dd>Touros</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 79.7 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Oceano</dd>\n<dt>City</dt><dd>Inhambane</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Weather Description</dt><dd>light rain and 76.51 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maitai Lapita Village Huahine</dd>\n<dt>City</dt><dd>Fare</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>light rain and 81.12 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Ambulu Jember</dd>\n<dt>City</dt><dd>Ambulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>clear sky and 85.44 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sulthan Hotel International</dd>\n<dt>City</dt><dd>Banda Aceh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 81.19 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Hotel Victoria</dd>\n<dt>City</dt><dd>Puerto Carreno</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 84.97 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fengshui Residence</dd>\n<dt>City</dt><dd>Port-Gentil</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Weather Description</dt><dd>few clouds and 78.8 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ASTON Samarinda Hotel & Convention Center</dd>\n<dt>City</dt><dd>Samarinda</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>light rain and 87.44 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maqna Hotel by Prasanthi</dd>\n<dt>City</dt><dd>Gorontalo</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 89.15 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Flat Temporada</dd>\n<dt>City</dt><dd>Tarauaca</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>broken clouds and 71.98 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Yogi Home Stay</dd>\n<dt>City</dt><dd>Kanakapura</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>broken clouds and 70.84 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>hostal sueños</dd>\n<dt>City</dt><dd>Matanzas</dd>\n<dt>Country</dt><dd>CU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 70.61 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Chik Chik Namibe</dd>\n<dt>City</dt><dd>Namibe</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 71.87 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sea Lounge! Bar, Club & Restaurant</dd>\n<dt>City</dt><dd>Itarema</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>clear sky and 77.88 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Fórum</dd>\n<dt>City</dt><dd>Luanda</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 75.45 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotels in Lakshadweep Islands</dd>\n<dt>City</dt><dd>Kavaratti</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>clear sky and 78.01 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>BON Hotel Waterfront Richards Bay</dd>\n<dt>City</dt><dd>Richards Bay</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>broken clouds and 71.83 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sylvia Hotel</dd>\n<dt>City</dt><dd>Maumere</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>few clouds and 84.65 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sunbury Motor Inn</dd>\n<dt>City</dt><dd>Sunbury</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 84.85 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maui Seaside Hotel</dd>\n<dt>City</dt><dd>Kahului</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 78.96 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOSTAL MI CHALET - PARAMONGA</dd>\n<dt>City</dt><dd>Paramonga</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Weather Description</dt><dd>broken clouds and 70.47 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tuck Inn Yarra Valley Accommodation Healesville</dd>\n<dt>City</dt><dd>Healesville</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 84.9 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Al-bustan Hotel And Restaurant.</dd>\n<dt>City</dt><dd>Wajir</dd>\n<dt>Country</dt><dd>KE</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 73.27 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Grand Continental Kuala Terengganu (4 Star)</dd>\n<dt>City</dt><dd>Kuala Terengganu</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 82.35 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Taloa Heights</dd>\n<dt>City</dt><dd>Alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 73.29 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porteira</dd>\n<dt>City</dt><dd>Entre Rios</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 71.89 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pitucão Hotel e Restaurante</dd>\n<dt>City</dt><dd>Bom Jesus Do Itabapoana</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 73.38 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>DoubleFAG</dd>\n<dt>City</dt><dd>Labuhan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>broken clouds and 83.8 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel e Churrascaria Pantaneira</dd>\n<dt>City</dt><dd>Pocone</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>few clouds and 76.5 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Daru Lodge</dd>\n<dt>City</dt><dd>Daru</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>broken clouds and 89.78 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pekan Budget Hotel</dd>\n<dt>City</dt><dd>Pekan</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 82.51 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fuente del Guania Hotel de Lujo</dd>\n<dt>City</dt><dd>Inirida</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Weather Description</dt><dd>broken clouds and 73.78 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>hotêl doufoulougou</dd>\n<dt>City</dt><dd>Tabou</dd>\n<dt>Country</dt><dd>CI</dd>\n<dt>Weather Description</dt><dd>moderate rain and 77.9 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Verde Hotel</dd>\n<dt>City</dt><dd>Eldorado</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>light rain and 72.09 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Commodore</dd>\n<dt>City</dt><dd>Mount Gambier</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 84.11 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Leumerus Bungalows</dd>\n<dt>City</dt><dd>Sola</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Weather Description</dt><dd>light rain and 82.26 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Pousada Nossa Senhora do Carmo</dd>\n<dt>City</dt><dd>Iguape</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>moderate rain and 77.05 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>JB Hotel</dd>\n<dt>City</dt><dd>Petrolina</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>light rain and 77.05 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Timotel Hotel</dd>\n<dt>City</dt><dd>Mersing</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 82.31 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Vilia Hotel</dd>\n<dt>City</dt><dd>Tual</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>broken clouds and 83.39 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pondok Wisata Elim</dd>\n<dt>City</dt><dd>Waingapu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>broken clouds and 86.14 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Les pailles en queue de Sainte Marie</dd>\n<dt>City</dt><dd>Sainte-Marie</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Weather Description</dt><dd>light intensity drizzle rain and 78.96 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kou-Bugny</dd>\n<dt>City</dt><dd>Vao</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Weather Description</dt><dd>few clouds and 80.83 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Salama and Fast Food</dd>\n<dt>City</dt><dd>Ambanja</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Weather Description</dt><dd>broken clouds and 70.99 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Porto do Sol</dd>\n<dt>City</dt><dd>Guarapari</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>clear sky and 76.89 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Solomon Debebe Hotel</dd>\n<dt>City</dt><dd>Gambela</dd>\n<dt>Country</dt><dd>ET</dd>\n<dt>Weather Description</dt><dd>few clouds and 74.52 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Monte Carmelo O Pão</dd>\n<dt>City</dt><dd>Belmonte</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>few clouds and 73.9 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospedaje Costa Bella</dd>\n<dt>City</dt><dd>Sechura</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Weather Description</dt><dd>few clouds and 70.99 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Gold N Rock Hotel Nigeria Limited</dd>\n<dt>City</dt><dd>Oyo</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Weather Description</dt><dd>clear sky and 72.66 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Citra</dd>\n<dt>City</dt><dd>Sabang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 82.02 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Bay Resort</dd>\n<dt>City</dt><dd>Ahuimanu</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 78.78 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tharrakamma Guest House</dd>\n<dt>City</dt><dd>Vredendal</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 71.89 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shandrani Beachcomber Resort & Spa</dd>\n<dt>City</dt><dd>Mahebourg</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 80.26 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mondkor Town, Bagbo Chiefdom, Bo District</dd>\n<dt>City</dt><dd>Mattru</dd>\n<dt>Country</dt><dd>SL</dd>\n<dt>Weather Description</dt><dd>broken clouds and 71.11 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Syariah CN Darussalam</dd>\n<dt>City</dt><dd>Sibolga</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 80.11 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kununurra</dd>\n<dt>City</dt><dd>Kununurra</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 85.98 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Galvão</dd>\n<dt>City</dt><dd>Santa Quiteria Do Maranhao</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>moderate rain and 73.0 °F </dd>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Ha'apai Beach Resort</dd>\n<dt>City</dt><dd>Pangai</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Weather Description</dt><dd>moderate rain and 77.2 °F </dd>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Moland Beach Resort</dd>\n<dt>City</dt><dd>Idenao</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 77.22 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Seagulls Inn Namatani</dd>\n<dt>City</dt><dd>Namatanai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>broken clouds and 86.41 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Amaloh Boutique Resort</dd>\n<dt>City</dt><dd>Matara</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Weather Description</dt><dd>few clouds and 77.86 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kitnet do Marcos</dd>\n<dt>City</dt><dd>Portel</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>moderate rain and 73.89 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Le Lagon</dd>\n<dt>City</dt><dd>Noumea</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Weather Description</dt><dd>moderate rain and 87.78 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Araguaia Palace Hotel</dd>\n<dt>City</dt><dd>Alto Araguaia</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 70.48 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Radisson Grenada Beach Resort</dd>\n<dt>City</dt><dd>Saint-Georges</dd>\n<dt>Country</dt><dd>GD</dd>\n<dt>Weather Description</dt><dd>few clouds and 76.68 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Panorama</dd>\n<dt>City</dt><dd>Itupiranga</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 72.23 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel de Stephen</dd>\n<dt>City</dt><dd>Bolobo</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Weather Description</dt><dd>light rain and 73.51 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sunset Inn</dd>\n<dt>City</dt><dd>Monrovia</dd>\n<dt>Country</dt><dd>LR</dd>\n<dt>Weather Description</dt><dd>light rain and 78.91 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Camp Pālehua</dd>\n<dt>City</dt><dd>Nanakuli</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 80.04 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Mpampa</dd>\n<dt>City</dt><dd>Soyo</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 77.49 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Batalla’s Lodging House</dd>\n<dt>City</dt><dd>Balabac</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>broken clouds and 81.5 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Storyboard Beach Resort</dd>\n<dt>City</dt><dd>Kloulklubed</dd>\n<dt>Country</dt><dd>PW</dd>\n<dt>Weather Description</dt><dd>broken clouds and 84.7 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Recanto dos Pássaros</dd>\n<dt>City</dt><dd>Sao Sebastiao</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 76.84 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Puri Brata</dd>\n<dt>City</dt><dd>Srandakan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>broken clouds and 71.73 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bichito</dd>\n<dt>City</dt><dd>Chimore</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Weather Description</dt><dd>heavy intensity rain and 71.87 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mercure Hotel Mildura</dd>\n<dt>City</dt><dd>Mildura</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 88.07 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HS Hotsson Smart Acapulco</dd>\n<dt>City</dt><dd>Acapulco</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky and 76.44 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Mirante Do Parque</dd>\n<dt>City</dt><dd>Penha</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>moderate rain and 77.16 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Olako</dd>\n<dt>City</dt><dd>Omboue</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Weather Description</dt><dd>clear sky and 76.03 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Purnama Hotel</dd>\n<dt>City</dt><dd>Limbang</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 86.11 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hostal Rio Miel</dd>\n<dt>City</dt><dd>Baracoa</dd>\n<dt>Country</dt><dd>CU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 74.68 °F </dd>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sheffield House Bed & Breakfast</dd>\n<dt>City</dt><dd>Kailua</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>clear sky and 80.58 °F </dd>\n']

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df['City'] == 'Bathurst']
vacation_end = vacation_df.loc[vacation_df['City'] == 'Bathurst']
vacation_stop1 = vacation_df.loc[vacation_df['City'] == 'Leeton']
vacation_stop2 = vacation_df.loc[vacation_df['City'] == 'Mildura'] 
vacation_stop3 = vacation_df.loc[vacation_df['City'] == 'Broken Hill']

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
import numpy as np

start = vacation_start['Lat'].to_numpy()[0], vacation_start['Lng'].to_numpy()[0]
end = vacation_end['Lat'].to_numpy()[0], vacation_end['Lng'].to_numpy()[0]
stop1 = vacation_stop1['Lat'].to_numpy()[0], vacation_stop1['Lng'].to_numpy()[0]
stop2 = vacation_stop2['Lat'].to_numpy()[0], vacation_stop1['Lng'].to_numpy()[0]
stop3 = vacation_stop3['Lat'].to_numpy()[0], vacation_stop1['Lng'].to_numpy()[0]

coords_stop1 = vacation_stop1['Lat'].to_numpy()[0], vacation_stop1['Lng'].to_numpy()[0]
coords_stop2 = vacation_stop2['Lat'].to_numpy()[0], vacation_stop2['Lng'].to_numpy()[0]
coords_stop3 = vacation_stop3['Lat'].to_numpy()[0], vacation_stop3['Lng'].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
city_itinerary = gmaps.directions_layer(
        start, end, waypoints=[coords_stop1, coords_stop2, coords_stop3],
        travel_mode='DRIVING')

fig.add_layer(city_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_end,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID         City Country  Max Temp       Description      Lat  \
# 0      240     Bathurst      AU     74.71  scattered clouds -33.4166
# 1      204       Leeton      AU     80.89         clear sky -34.5667
# 2      674      Mildura      AU     88.07     broken clouds -34.2000
# 3      256  Broken Hill      AU     80.31  scattered clouds -31.9500
#
#         Lng                Hotel Name
# 0  149.5806        Bathurst Motor Inn
# 1  146.4000  Historic Hydro Motor Inn
# 2  142.1500     Mercure Hotel Mildura
# 3  141.4333      Royal Exchange Hotel

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Description} and {Max Temp} °F </dd>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

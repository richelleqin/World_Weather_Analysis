# %%
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import json
import time
from datetime import datetime
import pandas as pd
import os

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
coordinates[:10]
# Out:
# [(-2.866602950242111, -19.483365944963538),
#  (-20.74236121048655, -157.93009109508003),
#  (-28.739090436279213, -24.398312232212277),
#  (-88.7806722543851, -49.02326250766731),
#  (-78.8610372481621, 179.17436936929363),
#  (-7.138740388119729, 15.891603389363212),
#  (4.702816672136805, 31.77136219878136),
#  (52.38386100970459, -58.80281319020807),
#  (57.63696111909741, -166.29419926325576),
#  (1.0931277559806176, -133.42773632932867)]

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
print(cities[:5])
# Out:
# ['georgetown', 'avarua', 'vila velha', 'ushuaia', 'kaitangata']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bea9f9a1eaac24a62ac9626e56a05e2e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
 

    # Group cities in sets of 50 for logging purposes.
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})
                            
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | vila velha
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | kaitangata
# Processing Record 6 of Set 1 | uige
# Processing Record 7 of Set 1 | juba
# Processing Record 8 of Set 1 | saint-augustin
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | christchurch
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | beringovskiy
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | esperance
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | vardo
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | faanui
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | tulagi
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | tsiroanomandidy
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | gizo
# Processing Record 32 of Set 1 | olenegorsk
# Processing Record 33 of Set 1 | sao filipe
# Processing Record 34 of Set 1 | scottsbluff
# Processing Record 35 of Set 1 | kamina
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | sept-iles
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | tocache
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | saint-leu
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | bathsheba
# Processing Record 48 of Set 1 | russell
# Processing Record 49 of Set 1 | malpe
# Processing Record 50 of Set 1 | fort frances
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | haines junction
# Processing Record 4 of Set 2 | walvis bay
# Processing Record 5 of Set 2 | tabas
# Processing Record 6 of Set 2 | bagdarin
# Processing Record 7 of Set 2 | khakurinokhabl
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | cascais
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | douglas
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | rocha
# Processing Record 15 of Set 2 | atar
# Processing Record 16 of Set 2 | zhigansk
# Processing Record 17 of Set 2 | dingle
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | rikitea
# Processing Record 21 of Set 2 | mirandopolis
# Processing Record 22 of Set 2 | lompoc
# Processing Record 23 of Set 2 | la primavera
# Processing Record 24 of Set 2 | martapura
# Processing Record 25 of Set 2 | dayong
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | kangaatsiaq
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | lamu
# Processing Record 30 of Set 2 | sao miguel
# Processing Record 31 of Set 2 | lamar
# Processing Record 32 of Set 2 | los llanos de aridane
# Processing Record 33 of Set 2 | karmana
# City not found. Skipping...
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | pevek
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | salalah
# Processing Record 39 of Set 2 | manado
# Processing Record 40 of Set 2 | constitucion
# Processing Record 41 of Set 2 | lavrentiya
# Processing Record 42 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 2 | clyde river
# Processing Record 44 of Set 2 | port hardy
# Processing Record 45 of Set 2 | port macquarie
# Processing Record 46 of Set 2 | lake elsinore
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | tombouctou
# Processing Record 49 of Set 2 | igrim
# Processing Record 50 of Set 2 | sal rei
# Processing Record 1 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | ilulissat
# Processing Record 4 of Set 3 | pisco
# Processing Record 5 of Set 3 | ahipara
# Processing Record 6 of Set 3 | naze
# Processing Record 7 of Set 3 | zemio
# Processing Record 8 of Set 3 | yulara
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | guerrero negro
# Processing Record 11 of Set 3 | pangkalanbuun
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | sajanan
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | kavieng
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | shumskiy
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | wattegama
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | dire dawa
# Processing Record 24 of Set 3 | xai-xai
# Processing Record 25 of Set 3 | vila franca do campo
# Processing Record 26 of Set 3 | chuy
# Processing Record 27 of Set 3 | kushmurun
# Processing Record 28 of Set 3 | sokoto
# Processing Record 29 of Set 3 | meulaboh
# Processing Record 30 of Set 3 | punta cardon
# Processing Record 31 of Set 3 | tasiilaq
# Processing Record 32 of Set 3 | dalvik
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | ahmadpur
# Processing Record 35 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | valparaiso
# Processing Record 38 of Set 3 | millville
# Processing Record 39 of Set 3 | bahawalpur
# Processing Record 40 of Set 3 | axim
# Processing Record 41 of Set 3 | bambous virieux
# Processing Record 42 of Set 3 | yaan
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | guilin
# Processing Record 45 of Set 3 | saint george
# Processing Record 46 of Set 3 | kabo
# Processing Record 47 of Set 3 | mar del plata
# Processing Record 48 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 3 | ruteng
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | mnogovershinnyy
# Processing Record 2 of Set 4 | jamestown
# Processing Record 3 of Set 4 | hambantota
# Processing Record 4 of Set 4 | george
# Processing Record 5 of Set 4 | kalmunai
# Processing Record 6 of Set 4 | asau
# Processing Record 7 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 4 | storforshei
# Processing Record 9 of Set 4 | vilyuysk
# Processing Record 10 of Set 4 | naliya
# Processing Record 11 of Set 4 | quelimane
# Processing Record 12 of Set 4 | muros
# Processing Record 13 of Set 4 | san cristobal
# Processing Record 14 of Set 4 | boralday
# Processing Record 15 of Set 4 | basudebpur
# Processing Record 16 of Set 4 | surt
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | razdolinsk
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | agdas
# Processing Record 21 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 4 | svetlyy
# Processing Record 23 of Set 4 | half moon bay
# Processing Record 24 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 4 | panama city
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | vozdvizhenka
# Processing Record 28 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 4 | portland
# Processing Record 30 of Set 4 | chincha alta
# Processing Record 31 of Set 4 | gewane
# Processing Record 32 of Set 4 | balsas
# Processing Record 33 of Set 4 | ponta do sol
# Processing Record 34 of Set 4 | hamilton
# Processing Record 35 of Set 4 | khudumelapye
# Processing Record 36 of Set 4 | deep river
# Processing Record 37 of Set 4 | nsukka
# Processing Record 38 of Set 4 | bocaranga
# City not found. Skipping...
# Processing Record 39 of Set 4 | victor harbor
# Processing Record 40 of Set 4 | san
# Processing Record 41 of Set 4 | tuktoyaktuk
# Processing Record 42 of Set 4 | jinchengjiang
# City not found. Skipping...
# Processing Record 43 of Set 4 | souillac
# Processing Record 44 of Set 4 | formosa
# Processing Record 45 of Set 4 | hobyo
# Processing Record 46 of Set 4 | port alfred
# Processing Record 47 of Set 4 | aksay
# Processing Record 48 of Set 4 | airai
# Processing Record 49 of Set 4 | filiatra
# Processing Record 50 of Set 4 | samarai
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | magadan
# Processing Record 3 of Set 5 | ancud
# Processing Record 4 of Set 5 | mumbwa
# Processing Record 5 of Set 5 | erenhot
# Processing Record 6 of Set 5 | astana
# Processing Record 7 of Set 5 | bredasdorp
# Processing Record 8 of Set 5 | bandarbeyla
# Processing Record 9 of Set 5 | yanam
# Processing Record 10 of Set 5 | gravdal
# Processing Record 11 of Set 5 | hoa binh
# Processing Record 12 of Set 5 | rio gallegos
# Processing Record 13 of Set 5 | uvat
# Processing Record 14 of Set 5 | bullhead city
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | kitwe
# Processing Record 17 of Set 5 | dengzhou
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | yerbogachen
# Processing Record 20 of Set 5 | leningradskiy
# Processing Record 21 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 5 | thompson
# Processing Record 23 of Set 5 | banjar
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | port lincoln
# Processing Record 26 of Set 5 | leeton
# Processing Record 27 of Set 5 | kribi
# Processing Record 28 of Set 5 | padang
# Processing Record 29 of Set 5 | porbandar
# Processing Record 30 of Set 5 | semey
# Processing Record 31 of Set 5 | alice springs
# Processing Record 32 of Set 5 | saint anthony
# Processing Record 33 of Set 5 | dawei
# Processing Record 34 of Set 5 | malindi
# Processing Record 35 of Set 5 | khatanga
# Processing Record 36 of Set 5 | hofn
# Processing Record 37 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 5 | minot
# Processing Record 39 of Set 5 | nabire
# Processing Record 40 of Set 5 | soc trang
# Processing Record 41 of Set 5 | townsville
# Processing Record 42 of Set 5 | qaqortoq
# Processing Record 43 of Set 5 | juneau
# Processing Record 44 of Set 5 | pascagoula
# Processing Record 45 of Set 5 | kungurtug
# Processing Record 46 of Set 5 | san quintin
# Processing Record 47 of Set 5 | ugoofaaru
# Processing Record 48 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 5 | biskamzha
# Processing Record 50 of Set 5 | raudeberg
# Processing Record 1 of Set 6 | dakar
# Processing Record 2 of Set 6 | saldanha
# Processing Record 3 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 6 | skopin
# Processing Record 5 of Set 6 | aguimes
# Processing Record 6 of Set 6 | baherden
# Processing Record 7 of Set 6 | candolim
# Processing Record 8 of Set 6 | caravelas
# Processing Record 9 of Set 6 | hualmay
# Processing Record 10 of Set 6 | santa maria
# Processing Record 11 of Set 6 | nagato
# Processing Record 12 of Set 6 | semnan
# Processing Record 13 of Set 6 | canutama
# Processing Record 14 of Set 6 | bathurst
# Processing Record 15 of Set 6 | makakilo city
# Processing Record 16 of Set 6 | brawley
# Processing Record 17 of Set 6 | arriaga
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | fortuna
# Processing Record 20 of Set 6 | sakakah
# Processing Record 21 of Set 6 | kokkola
# Processing Record 22 of Set 6 | lukovetskiy
# Processing Record 23 of Set 6 | sur
# Processing Record 24 of Set 6 | harper
# Processing Record 25 of Set 6 | usinsk
# Processing Record 26 of Set 6 | taltal
# Processing Record 27 of Set 6 | vitim
# Processing Record 28 of Set 6 | novosil
# Processing Record 29 of Set 6 | abeche
# Processing Record 30 of Set 6 | sidney
# Processing Record 31 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 32 of Set 6 | broken hill
# Processing Record 33 of Set 6 | dongsheng
# Processing Record 34 of Set 6 | cockburn town
# Processing Record 35 of Set 6 | tilichiki
# Processing Record 36 of Set 6 | okha
# Processing Record 37 of Set 6 | hami
# Processing Record 38 of Set 6 | kelso
# Processing Record 39 of Set 6 | ouahigouya
# Processing Record 40 of Set 6 | poum
# Processing Record 41 of Set 6 | yumen
# Processing Record 42 of Set 6 | kiunga
# Processing Record 43 of Set 6 | caiaponia
# Processing Record 44 of Set 6 | bagan
# Processing Record 45 of Set 6 | jiaocheng
# Processing Record 46 of Set 6 | sobolevo
# Processing Record 47 of Set 6 | bull savanna
# Processing Record 48 of Set 6 | pacific grove
# Processing Record 49 of Set 6 | lagoa
# Processing Record 50 of Set 6 | iqaluit
# Processing Record 1 of Set 7 | husavik
# Processing Record 2 of Set 7 | giyani
# Processing Record 3 of Set 7 | rawson
# Processing Record 4 of Set 7 | calatayud
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | grand gaube
# Processing Record 7 of Set 7 | ixtapa
# Processing Record 8 of Set 7 | marawi
# Processing Record 9 of Set 7 | provideniya
# Processing Record 10 of Set 7 | redlands
# Processing Record 11 of Set 7 | sabaudia
# Processing Record 12 of Set 7 | paamiut
# Processing Record 13 of Set 7 | yakshur-bodya
# City not found. Skipping...
# Processing Record 14 of Set 7 | ust-ilimsk
# Processing Record 15 of Set 7 | talnakh
# Processing Record 16 of Set 7 | lusambo
# Processing Record 17 of Set 7 | shashi
# Processing Record 18 of Set 7 | toora-khem
# Processing Record 19 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 7 | kenai
# Processing Record 21 of Set 7 | callaway
# Processing Record 22 of Set 7 | cururupu
# Processing Record 23 of Set 7 | ukiah
# Processing Record 24 of Set 7 | berkakit
# Processing Record 25 of Set 7 | bose
# Processing Record 26 of Set 7 | nicoya
# Processing Record 27 of Set 7 | etropole
# Processing Record 28 of Set 7 | firovo
# Processing Record 29 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 30 of Set 7 | general roca
# Processing Record 31 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 7 | shancheng
# Processing Record 33 of Set 7 | manggar
# Processing Record 34 of Set 7 | komsomolskiy
# Processing Record 35 of Set 7 | slave lake
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | ingham
# Processing Record 38 of Set 7 | bajil
# Processing Record 39 of Set 7 | maine-soroa
# Processing Record 40 of Set 7 | karratha
# Processing Record 41 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 7 | domoni
# Processing Record 43 of Set 7 | nhulunbuy
# Processing Record 44 of Set 7 | chicama
# Processing Record 45 of Set 7 | bontang
# Processing Record 46 of Set 7 | sao joao da barra
# Processing Record 47 of Set 7 | saint-joseph
# Processing Record 48 of Set 7 | wukari
# Processing Record 49 of Set 7 | hohhot
# Processing Record 50 of Set 7 | ankazoabo
# Processing Record 1 of Set 8 | goderich
# Processing Record 2 of Set 8 | opuwo
# Processing Record 3 of Set 8 | sitka
# Processing Record 4 of Set 8 | henties bay
# Processing Record 5 of Set 8 | yar-sale
# Processing Record 6 of Set 8 | yeppoon
# Processing Record 7 of Set 8 | belyy yar
# Processing Record 8 of Set 8 | akita
# Processing Record 9 of Set 8 | yarada
# Processing Record 10 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 8 | bubaque
# Processing Record 12 of Set 8 | qarqin
# Processing Record 13 of Set 8 | lasa
# Processing Record 14 of Set 8 | kaabong
# Processing Record 15 of Set 8 | ponta delgada
# Processing Record 16 of Set 8 | natal
# Processing Record 17 of Set 8 | isaccea
# Processing Record 18 of Set 8 | aswan
# Processing Record 19 of Set 8 | felipe carrillo puerto
# Processing Record 20 of Set 8 | araceli
# Processing Record 21 of Set 8 | batsfjord
# Processing Record 22 of Set 8 | isangel
# Processing Record 23 of Set 8 | piacabucu
# Processing Record 24 of Set 8 | north bend
# Processing Record 25 of Set 8 | bam
# Processing Record 26 of Set 8 | saint-pacome
# City not found. Skipping...
# Processing Record 27 of Set 8 | auki
# Processing Record 28 of Set 8 | abu kamal
# Processing Record 29 of Set 8 | roald
# Processing Record 30 of Set 8 | san ramon
# Processing Record 31 of Set 8 | ayan
# Processing Record 32 of Set 8 | broome
# Processing Record 33 of Set 8 | nichinan
# Processing Record 34 of Set 8 | dong xoai
# Processing Record 35 of Set 8 | ifanadiana
# Processing Record 36 of Set 8 | aklavik
# Processing Record 37 of Set 8 | nemuro
# Processing Record 38 of Set 8 | lodja
# Processing Record 39 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 8 | kutum
# Processing Record 41 of Set 8 | traralgon
# Processing Record 42 of Set 8 | high level
# Processing Record 43 of Set 8 | tazovskiy
# Processing Record 44 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 8 | nezhinka
# Processing Record 46 of Set 8 | homer
# Processing Record 47 of Set 8 | sturgeon falls
# Processing Record 48 of Set 8 | tiznit
# Processing Record 49 of Set 8 | gilbues
# Processing Record 50 of Set 8 | beloha
# Processing Record 1 of Set 9 | marystown
# Processing Record 2 of Set 9 | mayo
# Processing Record 3 of Set 9 | berlevag
# Processing Record 4 of Set 9 | port hawkesbury
# Processing Record 5 of Set 9 | chardara
# Processing Record 6 of Set 9 | cavalcante
# Processing Record 7 of Set 9 | margate
# Processing Record 8 of Set 9 | blanes
# Processing Record 9 of Set 9 | alyangula
# Processing Record 10 of Set 9 | benjamin constant
# Processing Record 11 of Set 9 | cananea
# Processing Record 12 of Set 9 | ruwi
# Processing Record 13 of Set 9 | chapais
# Processing Record 14 of Set 9 | charters towers
# Processing Record 15 of Set 9 | bosaso
# Processing Record 16 of Set 9 | coos bay
# Processing Record 17 of Set 9 | west wendover
# Processing Record 18 of Set 9 | daitari
# Processing Record 19 of Set 9 | batticaloa
# Processing Record 20 of Set 9 | pompeu
# Processing Record 21 of Set 9 | valdivia
# Processing Record 22 of Set 9 | tessalit
# Processing Record 23 of Set 9 | mumford
# Processing Record 24 of Set 9 | benguela
# Processing Record 25 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 9 | ghanzi
# Processing Record 27 of Set 9 | longyearbyen
# Processing Record 28 of Set 9 | karakol
# Processing Record 29 of Set 9 | dekar
# Processing Record 30 of Set 9 | atsiki
# City not found. Skipping...
# Processing Record 31 of Set 9 | magadi
# Processing Record 32 of Set 9 | anastacio
# Processing Record 33 of Set 9 | beaverlodge
# Processing Record 34 of Set 9 | santa cruz de la palma
# Processing Record 35 of Set 9 | maunabo
# Processing Record 36 of Set 9 | mbandaka
# Processing Record 37 of Set 9 | nishihara
# Processing Record 38 of Set 9 | grindavik
# Processing Record 39 of Set 9 | bairiki
# Processing Record 40 of Set 9 | cazaje
# City not found. Skipping...
# Processing Record 41 of Set 9 | belgrade
# Processing Record 42 of Set 9 | waynesville
# Processing Record 43 of Set 9 | himora
# City not found. Skipping...
# Processing Record 44 of Set 9 | pemangkat
# Processing Record 45 of Set 9 | grand bend
# Processing Record 46 of Set 9 | fengzhen
# Processing Record 47 of Set 9 | touros
# Processing Record 48 of Set 9 | inhambane
# Processing Record 49 of Set 9 | fare
# Processing Record 50 of Set 9 | yining
# Processing Record 1 of Set 10 | thinadhoo
# Processing Record 2 of Set 10 | neepawa
# Processing Record 3 of Set 10 | bud
# Processing Record 4 of Set 10 | yuci
# Processing Record 5 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 10 | ambulu
# Processing Record 7 of Set 10 | karasuk
# Processing Record 8 of Set 10 | takhatpur
# Processing Record 9 of Set 10 | banda aceh
# Processing Record 10 of Set 10 | cap-aux-meules
# Processing Record 11 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 10 | puerto carreno
# Processing Record 13 of Set 10 | ostersund
# Processing Record 14 of Set 10 | port-gentil
# Processing Record 15 of Set 10 | palmonostora
# Processing Record 16 of Set 10 | high rock
# Processing Record 17 of Set 10 | kushiro
# Processing Record 18 of Set 10 | samarinda
# Processing Record 19 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 10 | villa guerrero
# Processing Record 21 of Set 10 | nador
# Processing Record 22 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 23 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 10 | segezha
# Processing Record 25 of Set 10 | tailai
# Processing Record 26 of Set 10 | adrar
# Processing Record 27 of Set 10 | egvekinot
# Processing Record 28 of Set 10 | gorontalo
# Processing Record 29 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 30 of Set 10 | tiksi
# Processing Record 31 of Set 10 | muroto
# Processing Record 32 of Set 10 | roebourne
# Processing Record 33 of Set 10 | tarauaca
# Processing Record 34 of Set 10 | mount isa
# Processing Record 35 of Set 10 | kanakapura
# Processing Record 36 of Set 10 | benghazi
# Processing Record 37 of Set 10 | matanzas
# Processing Record 38 of Set 10 | novorudnyy
# Processing Record 39 of Set 10 | chistogorskiy
# Processing Record 40 of Set 10 | graham
# Processing Record 41 of Set 10 | namibe
# Processing Record 42 of Set 10 | tormac
# Processing Record 43 of Set 10 | north myrtle beach
# Processing Record 44 of Set 10 | narsaq
# Processing Record 45 of Set 10 | naqadeh
# Processing Record 46 of Set 10 | northam
# Processing Record 47 of Set 10 | nome
# Processing Record 48 of Set 10 | itarema
# Processing Record 49 of Set 10 | saurimo
# Processing Record 50 of Set 10 | vernon
# Processing Record 1 of Set 11 | luanda
# Processing Record 2 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 11 | shelburne
# Processing Record 4 of Set 11 | kavaratti
# Processing Record 5 of Set 11 | tigre
# Processing Record 6 of Set 11 | jalu
# Processing Record 7 of Set 11 | hazorasp
# Processing Record 8 of Set 11 | richards bay
# Processing Record 9 of Set 11 | lensk
# Processing Record 10 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 11 of Set 11 | las cruces
# Processing Record 12 of Set 11 | qasigiannguit
# Processing Record 13 of Set 11 | maumere
# Processing Record 14 of Set 11 | doha
# Processing Record 15 of Set 11 | plettenberg bay
# Processing Record 16 of Set 11 | kirovgrad
# Processing Record 17 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 18 of Set 11 | moose factory
# Processing Record 19 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 20 of Set 11 | rumonge
# Processing Record 21 of Set 11 | sunbury
# Processing Record 22 of Set 11 | coihaique
# Processing Record 23 of Set 11 | kahului
# Processing Record 24 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 11 | shenjiamen
# Processing Record 26 of Set 11 | chara
# Processing Record 27 of Set 11 | nara
# Processing Record 28 of Set 11 | college place
# Processing Record 29 of Set 11 | yashan
# Processing Record 30 of Set 11 | macusani
# Processing Record 31 of Set 11 | paramonga
# Processing Record 32 of Set 11 | ljungby
# Processing Record 33 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 11 | harstad
# Processing Record 35 of Set 11 | healesville
# Processing Record 36 of Set 11 | concarneau
# Processing Record 37 of Set 11 | beyneu
# Processing Record 38 of Set 11 | hovd
# Processing Record 39 of Set 11 | nizhneangarsk
# Processing Record 40 of Set 11 | wajir
# Processing Record 41 of Set 11 | qarayeri
# Processing Record 42 of Set 11 | kuala terengganu
# Processing Record 43 of Set 11 | alofi
# Processing Record 44 of Set 11 | santona
# Processing Record 45 of Set 11 | vostok
# Processing Record 46 of Set 11 | entre rios
# Processing Record 47 of Set 11 | bom jesus do itabapoana
# Processing Record 48 of Set 11 | pachino
# Processing Record 49 of Set 11 | tuatapere
# Processing Record 50 of Set 11 | maromitsa
# Processing Record 1 of Set 12 | labuhan
# Processing Record 2 of Set 12 | bronnoysund
# Processing Record 3 of Set 12 | karasjok
# Processing Record 4 of Set 12 | pocone
# Processing Record 5 of Set 12 | daru
# Processing Record 6 of Set 12 | vestmannaeyjar
# Processing Record 7 of Set 12 | pekan
# Processing Record 8 of Set 12 | sangar
# Processing Record 9 of Set 12 | burnie
# Processing Record 10 of Set 12 | sterling
# Processing Record 11 of Set 12 | yefimovskiy
# City not found. Skipping...
# Processing Record 12 of Set 12 | inirida
# Processing Record 13 of Set 12 | sheridan
# Processing Record 14 of Set 12 | kragujevac
# Processing Record 15 of Set 12 | olafsvik
# Processing Record 16 of Set 12 | hay river
# Processing Record 17 of Set 12 | sirathu
# Processing Record 18 of Set 12 | kodiak
# Processing Record 19 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 20 of Set 12 | santa vitoria do palmar
# Processing Record 21 of Set 12 | tabou
# Processing Record 22 of Set 12 | bad krozingen
# Processing Record 23 of Set 12 | ketchikan
# Processing Record 24 of Set 12 | eldorado
# Processing Record 25 of Set 12 | winburg
# Processing Record 26 of Set 12 | mount gambier
# Processing Record 27 of Set 12 | auch
# Processing Record 28 of Set 12 | suntar
# Processing Record 29 of Set 12 | sola
# Processing Record 30 of Set 12 | madimba
# Processing Record 31 of Set 12 | iguape
# Processing Record 32 of Set 12 | aykhal
# Processing Record 33 of Set 12 | korla
# Processing Record 34 of Set 12 | lososina
# Processing Record 35 of Set 12 | pokosnoye
# Processing Record 36 of Set 12 | petrolina
# Processing Record 37 of Set 12 | san roque
# Processing Record 38 of Set 12 | konya
# Processing Record 39 of Set 12 | shimoda
# Processing Record 40 of Set 12 | kiruna
# Processing Record 41 of Set 12 | mersing
# Processing Record 42 of Set 12 | pokhara
# Processing Record 43 of Set 12 | wufeng
# Processing Record 44 of Set 12 | iranshahr
# Processing Record 45 of Set 12 | polovinnoye
# Processing Record 46 of Set 12 | kalamare
# Processing Record 47 of Set 12 | jhang
# Processing Record 48 of Set 12 | morehead
# Processing Record 49 of Set 12 | san juan
# Processing Record 50 of Set 12 | kalach-na-donu
# Processing Record 1 of Set 13 | soligalich
# Processing Record 2 of Set 13 | tual
# Processing Record 3 of Set 13 | rudbar
# Processing Record 4 of Set 13 | waingapu
# Processing Record 5 of Set 13 | sainte-marie
# Processing Record 6 of Set 13 | kuryk
# Processing Record 7 of Set 13 | dieppe
# Processing Record 8 of Set 13 | vao
# Processing Record 9 of Set 13 | porto santo
# Processing Record 10 of Set 13 | itoman
# Processing Record 11 of Set 13 | berdigestyakh
# Processing Record 12 of Set 13 | scituate
# Processing Record 13 of Set 13 | bay roberts
# Processing Record 14 of Set 13 | laramie
# Processing Record 15 of Set 13 | imeni poliny osipenko
# Processing Record 16 of Set 13 | prince rupert
# Processing Record 17 of Set 13 | raga
# Processing Record 18 of Set 13 | kedrovyy
# Processing Record 19 of Set 13 | shirokiy
# Processing Record 20 of Set 13 | yomou
# Processing Record 21 of Set 13 | nantucket
# Processing Record 22 of Set 13 | alzamay
# Processing Record 23 of Set 13 | artyom
# Processing Record 24 of Set 13 | ambanja
# Processing Record 25 of Set 13 | lae
# Processing Record 26 of Set 13 | norman wells
# Processing Record 27 of Set 13 | tromso
# Processing Record 28 of Set 13 | verkhnyaya inta
# Processing Record 29 of Set 13 | cuiluan
# Processing Record 30 of Set 13 | miraflores
# Processing Record 31 of Set 13 | guarapari
# Processing Record 32 of Set 13 | tshikapa
# Processing Record 33 of Set 13 | gambela
# Processing Record 34 of Set 13 | belmonte
# Processing Record 35 of Set 13 | nouadhibou
# Processing Record 36 of Set 13 | qiongshan
# Processing Record 37 of Set 13 | sechura
# Processing Record 38 of Set 13 | veraval
# Processing Record 39 of Set 13 | lyubech
# Processing Record 40 of Set 13 | oyo
# Processing Record 41 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 13 | borgarnes
# Processing Record 43 of Set 13 | nicolas bravo
# Processing Record 44 of Set 13 | bulawayo
# Processing Record 45 of Set 13 | okmulgee
# Processing Record 46 of Set 13 | sabang
# Processing Record 47 of Set 13 | ahuimanu
# Processing Record 48 of Set 13 | wilmington
# Processing Record 49 of Set 13 | ivnya
# Processing Record 50 of Set 13 | tanout
# Processing Record 1 of Set 14 | vredendal
# Processing Record 2 of Set 14 | bushehr
# Processing Record 3 of Set 14 | dunedin
# Processing Record 4 of Set 14 | palestine
# Processing Record 5 of Set 14 | san luis
# Processing Record 6 of Set 14 | chimbote
# Processing Record 7 of Set 14 | mahebourg
# Processing Record 8 of Set 14 | mattru
# Processing Record 9 of Set 14 | sibolga
# Processing Record 10 of Set 14 | minab
# Processing Record 11 of Set 14 | kurtamysh
# Processing Record 12 of Set 14 | kununurra
# Processing Record 13 of Set 14 | santa quiteria do maranhao
# Processing Record 14 of Set 14 | pangai
# Processing Record 15 of Set 14 | idenao
# Processing Record 16 of Set 14 | santa rosalia
# Processing Record 17 of Set 14 | namatanai
# Processing Record 18 of Set 14 | ouadda
# Processing Record 19 of Set 14 | koshki
# Processing Record 20 of Set 14 | price
# Processing Record 21 of Set 14 | matara
# Processing Record 22 of Set 14 | sukhobezvodnoye
# Processing Record 23 of Set 14 | antofagasta
# Processing Record 24 of Set 14 | riyadh
# Processing Record 25 of Set 14 | yellamanchili
# City not found. Skipping...
# Processing Record 26 of Set 14 | creel
# Processing Record 27 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 14 | palmer
# Processing Record 29 of Set 14 | dharampur
# Processing Record 30 of Set 14 | taywarah
# Processing Record 31 of Set 14 | portel
# Processing Record 32 of Set 14 | laguna
# Processing Record 33 of Set 14 | awbari
# Processing Record 34 of Set 14 | noumea
# Processing Record 35 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 14 | chiredzi
# Processing Record 37 of Set 14 | alto araguaia
# Processing Record 38 of Set 14 | canton
# Processing Record 39 of Set 14 | petawawa
# Processing Record 40 of Set 14 | whitehorse
# Processing Record 41 of Set 14 | miyako
# Processing Record 42 of Set 14 | avera
# Processing Record 43 of Set 14 | saint-georges
# Processing Record 44 of Set 14 | neustrelitz
# Processing Record 45 of Set 14 | nefteyugansk
# Processing Record 46 of Set 14 | itupiranga
# Processing Record 47 of Set 14 | carbondale
# Processing Record 48 of Set 14 | changde
# Processing Record 49 of Set 14 | amberley
# Processing Record 50 of Set 14 | megion
# Processing Record 1 of Set 15 | bolobo
# Processing Record 2 of Set 15 | kyshtovka
# Processing Record 3 of Set 15 | monrovia
# Processing Record 4 of Set 15 | nanakuli
# Processing Record 5 of Set 15 | puerto madryn
# Processing Record 6 of Set 15 | nuuk
# Processing Record 7 of Set 15 | rabat
# Processing Record 8 of Set 15 | llangefni
# Processing Record 9 of Set 15 | mezen
# Processing Record 10 of Set 15 | soyo
# Processing Record 11 of Set 15 | xudat
# Processing Record 12 of Set 15 | joshimath
# Processing Record 13 of Set 15 | nipawin
# Processing Record 14 of Set 15 | ghorawal
# Processing Record 15 of Set 15 | neya
# Processing Record 16 of Set 15 | evensk
# Processing Record 17 of Set 15 | ileza
# Processing Record 18 of Set 15 | fukue
# Processing Record 19 of Set 15 | balabac
# Processing Record 20 of Set 15 | kloulklubed
# Processing Record 21 of Set 15 | isernia
# Processing Record 22 of Set 15 | sao sebastiao
# Processing Record 23 of Set 15 | novobohdanivka
# Processing Record 24 of Set 15 | funtua
# Processing Record 25 of Set 15 | srandakan
# Processing Record 26 of Set 15 | port hedland
# Processing Record 27 of Set 15 | stornoway
# Processing Record 28 of Set 15 | aberdeen
# Processing Record 29 of Set 15 | chimore
# Processing Record 30 of Set 15 | waipawa
# Processing Record 31 of Set 15 | mildura
# Processing Record 32 of Set 15 | acapulco
# Processing Record 33 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 34 of Set 15 | srednekolymsk
# Processing Record 35 of Set 15 | peleduy
# Processing Record 36 of Set 15 | tabuk
# Processing Record 37 of Set 15 | sorland
# Processing Record 38 of Set 15 | penha
# Processing Record 39 of Set 15 | agua verde
# Processing Record 40 of Set 15 | mazara del vallo
# Processing Record 41 of Set 15 | baiyin
# Processing Record 42 of Set 15 | omboue
# Processing Record 43 of Set 15 | isagarh
# Processing Record 44 of Set 15 | kathmandu
# Processing Record 45 of Set 15 | nalut
# Processing Record 46 of Set 15 | genhe
# Processing Record 47 of Set 15 | limbang
# Processing Record 48 of Set 15 | tezu
# Processing Record 49 of Set 15 | pendleton
# Processing Record 50 of Set 15 | jorpeland
# Processing Record 1 of Set 16 | ongandjera
# Processing Record 2 of Set 16 | arlit
# Processing Record 3 of Set 16 | muskogee
# Processing Record 4 of Set 16 | pangnirtung
# Processing Record 5 of Set 16 | marsa matruh
# Processing Record 6 of Set 16 | nizhniy kuranakh
# Processing Record 7 of Set 16 | oga
# Processing Record 8 of Set 16 | mehamn
# Processing Record 9 of Set 16 | aksarka
# Processing Record 10 of Set 16 | saint-francois
# Processing Record 11 of Set 16 | taoudenni
# Processing Record 12 of Set 16 | baracoa
# Processing Record 13 of Set 16 | kailua
# Processing Record 14 of Set 16 | magnitogorsk
# Processing Record 15 of Set 16 | boulder
# Processing Record 16 of Set 16 | breyten
# Processing Record 17 of Set 16 | lapua
# Processing Record 18 of Set 16 | stromness
# -----------------------------
# Data Retrieval Complete

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Georgetown      MY   5.4112  100.3354     84.13        80          20
# 1          Avarua      CK -21.2078 -159.7750     82.45        74          40
# 2      Vila Velha      BR -20.3297  -40.2925     76.95        86           0
# 3         Ushuaia      AR -54.8000  -68.3000     49.66        57          20
# 4      Kaitangata      NZ -46.2817  169.8464     54.93        57          45
# ..            ...     ...      ...       ...       ...       ...         ...
# 706  Magnitogorsk      RU  53.4186   59.0472      9.43        85          75
# 707       Boulder      US  40.0833 -105.3505     32.32        43           0
# 708       Breyten      ZA -26.3018   29.9870     53.62        92         100
# 709         Lapua      FI  62.9693   23.0088     29.08        94           7
# 710     Stromness      GB  58.9650   -3.2960     34.05        65         100
#
#      Wind Speed       Description
# 0          5.01        few clouds
# 1         12.66  scattered clouds
# 2          8.05         clear sky
# 3         16.11        few clouds
# 4          8.43  scattered clouds
# ..          ...               ...
# 706       11.18     broken clouds
# 707        1.99         clear sky
# 708       11.63   overcast clouds
# 709        7.07         clear sky
# 710       31.54        light snow
#
# [711 rows x 9 columns]

# %%
directory_of_python_script = os.path.dirname(os.path.abspath('Weather_Database'))

city_data_df.to_csv(os.path.join(directory_of_python_script, "WeatherPy_Database.csv"))
